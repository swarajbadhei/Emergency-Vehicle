# %%
import os
import librosa
import numpy as np
import librosa

# %%
for subdir,dirs,files in os.walk('audio_data/ambulance/'):
    for filename in files:
        filepath=subdir+os.sep+filename
        if filepath.endswith('webm'):
            print(filepath)
# Out:
# audio_data/ambulance/\Ambulance_1.webm
# audio_data/ambulance/\Ambulance_10.webm
# audio_data/ambulance/\Ambulance_11.webm
# audio_data/ambulance/\Ambulance_12.webm
# audio_data/ambulance/\Ambulance_13.webm
# audio_data/ambulance/\Ambulance_14.webm
# audio_data/ambulance/\Ambulance_15.webm
# audio_data/ambulance/\Ambulance_16.webm
# audio_data/ambulance/\Ambulance_18.webm
# audio_data/ambulance/\Ambulance_19.webm
# audio_data/ambulance/\Ambulance_2.webm
# audio_data/ambulance/\Ambulance_20.webm
# audio_data/ambulance/\Ambulance_21.webm
# audio_data/ambulance/\Ambulance_22.webm
# audio_data/ambulance/\Ambulance_23.webm
# audio_data/ambulance/\Ambulance_24.webm
# audio_data/ambulance/\Ambulance_25.webm
# audio_data/ambulance/\Ambulance_26.webm
# audio_data/ambulance/\Ambulance_28.webm
# audio_data/ambulance/\Ambulance_29.webm
# audio_data/ambulance/\Ambulance_3.webm
# audio_data/ambulance/\Ambulance_5.webm
# audio_data/ambulance/\Ambulance_6.webm
# ...

# %%
arr=np.random.randint(low=10,high=20,size=(2,3))

# %%
arr
# Out:
# array([[11, 10, 11],
#        [19, 19, 12]])

# %%
arr=arr.flatten()

# %%
arr
# Out:
# array([11, 10, 11, 19, 19, 12])

# %%
arr.reshape(2,3)
# Out:
# array([[11, 10, 11],
#        [19, 19, 12]])

# %%
for subdir,dirs,files in os.walk('audio_data'):
    for filename in files:
        filepath=subdir+os.sep+filename
        if filepath.endswith('webm'):
            #print(filepath)
            if subdir=='audio_data\ambulance':
                print('inside')
# Out:
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\ambulance
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# audio_data\fire
# ...
