# %%
import pandas as pd
import numpy as np
import youtube_dl
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import pafy
import os

# %%
data=pd.read_csv('unbalanced_train_segments.csv')
# Out:
# C:\Users\Swaraj Badhei\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
targets=data.values[:,3:]

# %%
targets.shape
# Out:
# (1048572, 15)

# %%
police='/m/04qvtq'
ambu='/m/012n7d'
fire='/m/012ndj'
emer='/03j1ly'
emer_lst=[]
police_lst=[]
ambu_lst=[]
fire_lst=[]
for i in range(targets.shape[0]):
    #string=
    if police in targets[i,:]:
        police_lst.append([data.iloc[i,0],data.iloc[i,1],data.iloc[i,2]])
    elif fire in targets[i,:]:
        fire_lst.append([data.iloc[i,0],data.iloc[i,1],data.iloc[i,2]])
    elif ambu in targets[i,:]:
        ambu_lst.append([data.iloc[i,0],data.iloc[i,1],data.iloc[i,2]])
    else:
        pass

# %%
temp_police=police_lst

# %%
temp_police

# %%
print(np.array(temp_police).shape)

# %%
for j in range(1,4):
    x=temp_police.pop(j)

# %%
temp_police.pop(1)

# %%
temp_police

# %%
print(np.array(temp_police).shape)

# %%
print(np.array(fire_lst).shape)
# Out:
# (213, 3)

# %%
for i in range(np.array(fire_lst).shape[0]):
    try:
        ts=fire_lst[i][1]
        te=fire_lst[i][2]
        #print(te,ts)
        y_id=fire_lst[i][0]
        video_url='https://www.youtube.com/watch?v={}'.format(y_id)
        video=pafy.new(video_url)
        best_audio=video.getbestaudio()
        audio_name=best_audio.filename
        best_audio.download()
        if os.path.exists(audio_name):
            output_file='firetruck_'+str(i)+'.webm'
            ffmpeg_extract_subclip(audio_name,ts,te,targetname=output_file)
            os.remove(audio_name)
        print("DONE FOR {}".format(i))
    except:
        print('Error in file : {}'.format(i+1))
        pass
# Out:
#   561,864.0 Bytes [100.00%] received. Rate: [3368 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 0
#   854,872.0 Bytes [100.00%] received. Rate: [6370 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 1
#   1,140,798.0 Bytes [100.00%] received. Rate: [3587 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 2
#   44,495.0 Bytes [100.00%] received. Rate: [ 612 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 4
# Error in file : 5
# Error in file : 6
# Error in file : 7
# Error in file : 8
# Error in file : 9
#   2,581,040.0 Bytes [100.00%] received. Rate: [6736 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 9
#   648,544.0 Bytes [100.00%] received. Rate: [2988 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 10
#   2,418,392.0 Bytes [100.00%] received. Rate: [12088 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 11
#   11,175,081.0 Bytes [100.00%] received. Rate: [1002 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 12
#   835,162.0 Bytes [100.00%] received. Rate: [3274 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 13
#   3,051,870.0 Bytes [100.00%] received. Rate: [13049 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 14
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 16
#   836,009.0 Bytes [100.00%] received. Rate: [6249 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 16
#   24,948.0 Bytes [100.00%] received. Rate: [1110 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 18
#   4,147,528.0 Bytes [100.00%] received. Rate: [15364 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 18
#   12,400,887.0 Bytes [100.00%] received. Rate: [6299 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 19
#   13,790.0 Bytes [100.00%] received. Rate: [2249 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 21
#   1,505,821.0 Bytes [100.00%] received. Rate: [4554 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 21
#   6,576,531.0 Bytes [100.00%] received. Rate: [7391 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 22
#   2,794,252.0 Bytes [100.00%] received. Rate: [12600 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 23
#   4,270,089.0 Bytes [100.00%] received. Rate: [8833 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 24
#   983,342.0 Bytes [100.00%] received. Rate: [2573 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 25
#   196,508.0 Bytes [100.00%] received. Rate: [1582 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 26
#   1,117,811.0 Bytes [100.00%] received. Rate: [3787 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 27
#   18,310.0 Bytes [100.00%] received. Rate: [ 336 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 29
#   9,749.0 Bytes [100.00%] received. Rate: [ 795 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 30
#   2,528,514.0 Bytes [100.00%] received. Rate: [13023 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 30
#   23,220.0 Bytes [100.00%] received. Rate: [ 364 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 32
#   989,344.0 Bytes [100.00%] received. Rate: [3265 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 32
# ERROR: This video is no longer available because the YouTube account associated with this video has been terminated.
# Sorry about that.
# Error in file : 34
#   1,361,990.0 Bytes [100.00%] received. Rate: [4224 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 34
#   639,567.0 Bytes [100.00%] received. Rate: [2827 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 35
#   18,461.0 Bytes [100.00%] received. Rate: [ 329 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 37
#   309,264.0 Bytes [100.00%] received. Rate: [2037 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 37
#   421,551.0 Bytes [100.00%] received. Rate: [2084 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 38
#   8,832,232.0 Bytes [100.00%] received. Rate: [7248 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 39
#   137,770.0 Bytes [100.00%] received. Rate: [2546 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 40
#   558,349.0 Bytes [100.00%] received. Rate: [5158 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 41
#   412,991.0 Bytes [100.00%] received. Rate: [4494 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 42
#   781,070.0 Bytes [100.00%] received. Rate: [2929 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 43
#   409,924.0 Bytes [100.00%] received. Rate: [1997 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 44
#   5,763,005.0 Bytes [100.00%] received. Rate: [4717 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 45
#   971,440.0 Bytes [100.00%] received. Rate: [3422 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 46
#   5,484,909.0 Bytes [100.00%] received. Rate: [8672 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 47
#   7,984,373.0 Bytes [100.00%] received. Rate: [4568 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 48
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 50
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 51
#   475,969.0 Bytes [100.00%] received. Rate: [2416 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 51
#   1,467,435.0 Bytes [100.00%] received. Rate: [2906 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 52
#   1,138,766.0 Bytes [100.00%] received. Rate: [8774 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 53
#   1,296,445.0 Bytes [100.00%] received. Rate: [8352 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 54
#   3,385,632.0 Bytes [100.00%] received. Rate: [7617 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 55
#   1,607,190.0 Bytes [100.00%] received. Rate: [10205 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 56
#   866,261.0 Bytes [100.00%] received. Rate: [6838 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 57
#   1,800,399.0 Bytes [100.00%] received. Rate: [10950 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 58
#   983,249.0 Bytes [100.00%] received. Rate: [3474 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 59
#   596,192.0 Bytes [100.00%] received. Rate: [5131 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 60
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 62
#   402,820.0 Bytes [100.00%] received. Rate: [4377 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 62
#   12,973.0 Bytes [100.00%] received. Rate: [ 605 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 64
#   5,768,097.0 Bytes [100.00%] received. Rate: [11232 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 64
#   10,292,664.0 Bytes [100.00%] received. Rate: [9852 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 65
#   13,560,750.0 Bytes [100.00%] received. Rate: [3835 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 66
#   1,154,805.0 Bytes [100.00%] received. Rate: [8495 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 67
#   835,192.0 Bytes [100.00%] received. Rate: [7030 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 68
#   4,163,789.0 Bytes [100.00%] received. Rate: [8994 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 69
#   4,854,605.0 Bytes [100.00%] received. Rate: [2449 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 70
#   13,654,715.0 Bytes [100.00%] received. Rate: [6402 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 71
#   1,011,571.0 Bytes [100.00%] received. Rate: [3578 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 72
#   457,912.0 Bytes [100.00%] received. Rate: [2134 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 73
#   2,903,810.0 Bytes [100.00%] received. Rate: [13207 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 74
#   26,361.0 Bytes [100.00%] received. Rate: [ 417 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 76
#   1,735,633.0 Bytes [100.00%] received. Rate: [5246 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 76
#   4,257,188.0 Bytes [100.00%] received. Rate: [7086 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 77
#   3,285,580.0 Bytes [100.00%] received. Rate: [7163 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 78
#   6,190,594.0 Bytes [100.00%] received. Rate: [5594 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 79
#   1,030,465.0 Bytes [100.00%] received. Rate: [3593 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 80
#   5,324,832.0 Bytes [100.00%] received. Rate: [11413 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 81
#   3,779,750.0 Bytes [100.00%] received. Rate: [7899 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 82
#   1,297,204.0 Bytes [100.00%] received. Rate: [8195 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 83
#   877,551.0 Bytes [100.00%] received. Rate: [6827 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 84
#   2,298,491.0 Bytes [100.00%] received. Rate: [5975 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 85
#   1,095,912.0 Bytes [100.00%] received. Rate: [8130 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 86
# ERROR: Content Warning
# If the owner of this video has granted you access, please sign in.
#        This video is private.
# Error in file : 88
#   3,194,630.0 Bytes [100.00%] received. Rate: [8092 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 88
#   2,389,329.0 Bytes [100.00%] received. Rate: [11244 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 89
#   11,630.0 Bytes [100.00%] received. Rate: [2327 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 91
#   2,938,195.0 Bytes [100.00%] received. Rate: [5287 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 91
#   1,633,888.0 Bytes [100.00%] received. Rate: [4998 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 92
#   524,143.0 Bytes [100.00%] received. Rate: [2553 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 93
#   438,503.0 Bytes [100.00%] received. Rate: [2398 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 94
#   25,115,797.0 Bytes [100.00%] received. Rate: [8540 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 95
#   1,147,621.0 Bytes [100.00%] received. Rate: [7484 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 96
#   157,289.0 Bytes [100.00%] received. Rate: [2139 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 97
#   2,125,651.0 Bytes [100.00%] received. Rate: [6028 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 98
#   2,088,560.0 Bytes [100.00%] received. Rate: [11413 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 99
#   98,066.0 Bytes [100.00%] received. Rate: [ 589 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 101
#   1,913,418.0 Bytes [100.00%] received. Rate: [10351 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 101
#   9,021,783.0 Bytes [100.00%] received. Rate: [3490 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 102
#   4,968,010.0 Bytes [100.00%] received. Rate: [4914 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 103
#   1,610,961.0 Bytes [100.00%] received. Rate: [4393 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 104
#   2,276,626.0 Bytes [100.00%] received. Rate: [5897 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 105
#   2,001,241.0 Bytes [100.00%] received. Rate: [5254 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 106
#   367,118.0 Bytes [100.00%] received. Rate: [2179 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 107
#   3,299,023.0 Bytes [100.00%] received. Rate: [5236 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 108
#   1,199,757.0 Bytes [100.00%] received. Rate: [8511 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 109
#   293,960.0 Bytes [100.00%] received. Rate: [3507 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 110
#   368,329.0 Bytes [100.00%] received. Rate: [2213 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 111
#   257,785.0 Bytes [100.00%] received. Rate: [1918 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 112
#   491,706.0 Bytes [100.00%] received. Rate: [4864 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 113
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 115
#   993,413.0 Bytes [100.00%] received. Rate: [3743 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 115
#   3,914,396.0 Bytes [100.00%] received. Rate: [9112 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 116
#   1,409,223.0 Bytes [100.00%] received. Rate: [4813 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 117
#   2,244,096.0 Bytes [100.00%] received. Rate: [6099 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 118
#   394,027.0 Bytes [100.00%] received. Rate: [2052 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 119
#   19,766,505.0 Bytes [100.00%] received. Rate: [7682 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 120
#   2,709,450.0 Bytes [100.00%] received. Rate: [2465 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 121
#   717,692.0 Bytes [100.00%] received. Rate: [5859 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 122
#   1,407,479.0 Bytes [100.00%] received. Rate: [4276 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 123
#   14,500.0 Bytes [100.00%] received. Rate: [1772 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 125
#   2,351,682.0 Bytes [100.00%] received. Rate: [6473 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 125
#   846,053.0 Bytes [100.00%] received. Rate: [3024 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 126
#   655,830.0 Bytes [100.00%] received. Rate: [5299 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 127
#   256,624.0 Bytes [100.00%] received. Rate: [1753 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 128
#   64,389.0 Bytes [100.00%] received. Rate: [ 690 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 130
#   1,891,145.0 Bytes [100.00%] received. Rate: [9942 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 130
#   5,991,245.0 Bytes [100.00%] received. Rate: [4559 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 131
#   1,076,314.0 Bytes [100.00%] received. Rate: [3717 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 132
#   503,948.0 Bytes [100.00%] received. Rate: [4446 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 133
#   1,084,295.0 Bytes [100.00%] received. Rate: [7173 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 134
#   879,398.0 Bytes [100.00%] received. Rate: [6946 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 135
#   841,093.0 Bytes [100.00%] received. Rate: [3028 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 136
#   227,680.0 Bytes [100.00%] received. Rate: [3139 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 137
#   3,410,731.0 Bytes [100.00%] received. Rate: [13849 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 138
#   3,616,657.0 Bytes [100.00%] received. Rate: [8216 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 139
#   470,644.0 Bytes [100.00%] received. Rate: [2158 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 140
#   41,148.0 Bytes [100.00%] received. Rate: [ 543 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 142
#   1,789,399.0 Bytes [100.00%] received. Rate: [5043 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 142
#   506,191.0 Bytes [100.00%] received. Rate: [4812 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 143
#   2,974,213.0 Bytes [100.00%] received. Rate: [6529 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 144
#   1,267,016.0 Bytes [100.00%] received. Rate: [8556 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 145
#   3,623,106.0 Bytes [100.00%] received. Rate: [8528 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 146
#   268,119.0 Bytes [100.00%] received. Rate: [1658 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 147
#   1,866,963.0 Bytes [100.00%] received. Rate: [7028 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 148
#   7,130,807.0 Bytes [100.00%] received. Rate: [5494 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 149
#   28,477.0 Bytes [100.00%] received. Rate: [1071 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 151
#   10,352.0 Bytes [100.00%] received. Rate: [ 267 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 152
#   10,238,825.0 Bytes [100.00%] received. Rate: [3183 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 152
#   211,951.0 Bytes [100.00%] received. Rate: [1941 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 153
#   1,277,226.0 Bytes [100.00%] received. Rate: [4667 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 154
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 156
#   979,241.0 Bytes [100.00%] received. Rate: [5035 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 156
#   3,484,187.0 Bytes [100.00%] received. Rate: [10259 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 157
#   325,538.0 Bytes [100.00%] received. Rate: [3927 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 158
#   21,222.0 Bytes [100.00%] received. Rate: [1154 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 160
#   2,531,404.0 Bytes [100.00%] received. Rate: [12154 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 160
#   1,142,917.0 Bytes [100.00%] received. Rate: [3752 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 161
#   747,887.0 Bytes [100.00%] received. Rate: [3238 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 162
#   5,343,913.0 Bytes [100.00%] received. Rate: [3654 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 163
#   1,542,172.0 Bytes [100.00%] received. Rate: [2237 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 164
#   14,454,012.0 Bytes [100.00%] received. Rate: [3298 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 165
#   4,006,157.0 Bytes [100.00%] received. Rate: [4973 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 166
#   25,094.0 Bytes [100.00%] received. Rate: [1068 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 168
#   3,698,279.0 Bytes [100.00%] received. Rate: [4106 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 168
#   600,854.0 Bytes [100.00%] received. Rate: [ 987 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 169
#   875,204.0 Bytes [100.00%] received. Rate: [1546 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 170
#   3,361,571.0 Bytes [100.00%] received. Rate: [2737 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 171
#   1,367,986.0 Bytes [100.00%] received. Rate: [2158 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 172
#   5,984,889.0 Bytes [100.00%] received. Rate: [2906 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 173
#   2,026,099.0 Bytes [100.00%] received. Rate: [5891 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 174
#   192,213.0 Bytes [100.00%] received. Rate: [1629 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 175
#   2,017,596.0 Bytes [100.00%] received. Rate: [5917 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 176
#   1,289,678.0 Bytes [100.00%] received. Rate: [8348 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 177
#   8,723,550.0 Bytes [100.00%] received. Rate: [2364 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 178
#   13,023.0 Bytes [100.00%] received. Rate: [ 394 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 180
#   547,715.0 Bytes [100.00%] received. Rate: [1084 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 180
#   15,092.0 Bytes [100.00%] received. Rate: [2462 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 182
#   609,096.0 Bytes [100.00%] received. Rate: [2709 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 182
#   14,397.0 Bytes [100.00%] received. Rate: [2021 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 184
#   1,858,778.0 Bytes [100.00%] received. Rate: [5258 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 184
#   10,537,143.0 Bytes [100.00%] received. Rate: [1697 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 185
#   624,439.0 Bytes [100.00%] received. Rate: [1174 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 186
#   1,421,700.0 Bytes [100.00%] received. Rate: [2134 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 187
#   290,432.0 Bytes [100.00%] received. Rate: [1698 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 188
#   60,873.0 Bytes [100.00%] received. Rate: [ 518 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 190
#   4,255,434.0 Bytes [100.00%] received. Rate: [4975 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 190
#   542,583.0 Bytes [100.00%] received. Rate: [2482 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 191
#   6,464,539.0 Bytes [100.00%] received. Rate: [3058 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 192
#   12,774,247.0 Bytes [100.00%] received. Rate: [1822 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 193
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 195
#   36,977,834.0 Bytes [100.00%] received. Rate: [1933 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 195
#   1,717,405.0 Bytes [100.00%] received. Rate: [2607 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 196
#   816,709.0 Bytes [100.00%] received. Rate: [1216 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 197
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file : 199
#   3,270,986.0 Bytes [100.00%] received. Rate: [3071 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 199
#   904,864.0 Bytes [100.00%] received. Rate: [1174 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 200
#   488,885.0 Bytes [100.00%] received. Rate: [ 976 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 201
#   1,901,745.0 Bytes [100.00%] received. Rate: [2710 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 202
#   26,641.0 Bytes [100.00%] received. Rate: [ 330 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 204
#   297,903.0 Bytes [100.00%] received. Rate: [ 770 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 204
#   593,432.0 Bytes [100.00%] received. Rate: [1126 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 205
#   13,395,519.0 Bytes [100.00%] received. Rate: [2414 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 206
#   1,849,875.0 Bytes [100.00%] received. Rate: [2579 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 207
#   10,142,350.0 Bytes [100.00%] received. Rate: [ 356 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 208
#   2,803,002.0 Bytes [100.00%] received. Rate: [3195 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 209
#   17,123.0 Bytes [100.00%] received. Rate: [ 932 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file : 211
#   1,918,837.0 Bytes [100.00%] received. Rate: [2863 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 211
#   8,468,492.0 Bytes [100.00%] received. Rate: [2939 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 212

# %%
police_lst[230][:]
