# %%
import pandas as pd
import numpy as np
import youtube_dl
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import pafy
import os

# %%
data=pd.read_csv('unbalanced_train_segments.csv')
# Out:
# C:\Users\Swaraj Badhei\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
targets=data.values[:,3:]

# %%
targets.shape
# Out:
# (1048563, 15)

# %%
police='/m/04qvtq'
ambu='/m/012n7d'
fire='/m/012ndj'
emer='/03j1ly'
emer_lst=[]
police_lst=[]
ambu_lst=[]
fire_lst=[]
for i in range(targets.shape[0]):
    #string=
    if police in targets[i,:]:
        police_lst.append([data.iloc[i,0],data.iloc[i,1],data.iloc[i,2]])
    elif fire in targets[i,:]:
        fire_lst.append([data.iloc[i,0],data.iloc[i,1],data.iloc[i,2]])
    elif ambu in targets[i,:]:
        ambu_lst.append([data.iloc[i,0],data.iloc[i,1],data.iloc[i,2]])
    else:
        pass

# %%
temp_police=police_lst

# %%
temp_police
# Out:
# [['-122tCXtFhU', 30.0, 40.0],
#  ['#NAME?', 9.0, 19.0],
#  ['#NAME?', 350.0, 360.0],
#  ['#NAME?', 10.0, 20.0],
#  ['#NAME?', 10.0, 20.0],
#  ['#NAME?', 3.0, 13.0],
#  ['#NAME?', 8.0, 18.0],
#  ['#NAME?', 0.0, 10.0],
#  ['09dzay_jgNs', 30.0, 40.0],
#  ['0Fv4lkRB-BM', 140.0, 150.0],
#  ['0I6Mlp27_gM', 30.0, 40.0],
#  ['0Y98tzWJkjw', 140.0, 150.0],
#  ['0rKDe5UNSlk', 30.0, 40.0],
#  ['0xbnKT0lTZY', 7.0, 17.0],
#  ['12K4PFm6afY', 0.0, 10.0],
#  ['12aXUfObwlY', 0.0, 10.0],
#  ['1NVfl7AnSRg', 30.0, 40.0],
#  ['1PPn02f5M2U', 3.0, 13.0],
#  ['1W-yspM_mns', 30.0, 40.0],
#  ['1XPr0mGp4JI', 30.0, 40.0],
#  ['1Y-X9sA1V0w', 30.0, 40.0],
#  ['1Yxm08Q5j04', 14.0, 24.0],
#  ['1aXQVJWpgKQ', 30.0, 40.0],
#  ['1menriOu8xI', 10.0, 20.0],
#  ['1pLOAHXZTdQ', 0.0, 10.0],
#  ['1tdGqmmMvN8', 30.0, 40.0],
#  ['1wxDPv-U7XI', 20.0, 30.0],
#  ['1z1x1KrGWVw', 150.0, 160.0],
#  ['20QEXBty5iY', 27.0, 37.0],
#  ['256ESX-Fe90', 30.0, 40.0],
#  ['2DC5uZcrhcY', 10.0, 20.0],
#  ['2MHhtDe72Sc', 50.0, 60.0],
#  ['2NU-ij1hO2c', 30.0, 40.0],
#  ['2NlASv1Z5IY', 30.0, 40.0],
#  ['2S3bd7jBX0Q', 10.0, 20.0],
#  ['2fS6PbFGVKw', 25.0, 35.0],
#  ['2jXPc6IC1zE', 20.0, 30.0],
#  ['2xWH7McfIVA', 50.0, 60.0],
#  ['2zusC8gWnXw', 24.0, 34.0],
#  ['35t3MVCE160', 30.0, 40.0],
#  ['3T1z1c3Z_Es', 40.0, 50.0],
#  ['3UE_AQZ9RNU', 30.0, 40.0],
#  ['3gJkDVFdBSc', 30.0, 40.0],
#  ['3jEK-hQZshU', 0.0, 10.0],
#  ['3sVWGc8Z7F4', 30.0, 40.0],
#  ['447Tv2wYwR0', 21.0, 31.0],
#  ['495SjWHEz7Q', 25.0, 35.0],
#  ['4vdEmK_Ywhs', 30.0, 40.0],
#  ['50UkIXNt9M8', 30.0, 40.0],
#  ['57NefYJLTE4', 30.0, 40.0],
#  ['5EueOObOVGw', 16.0, 26.0],
#  ['5UEANjv4EaQ', 3.0, 13.0],
#  ['5XkYYom37u0', 7.0, 17.0],
#  ['5_6WkhNqyN4', 4.0, 14.0],
#  ['5eNOKWmmCcI', 30.0, 40.0],
#  ['5om-tsbyY9M', 0.0, 10.0],
#  ['5p-XAJdzqPc', 30.0, 40.0],
#  ['5sicVdGVYco', 30.0, 40.0],
#  ['5tb_c-jFqMw', 30.0, 40.0],
#  ['5z-qZv3F2V0', 200.0, 210.0],
#  ['6GJY_1ThSNY', 23.0, 33.0],
#  ['6HqoI_24yE4', 40.0, 50.0],
#  ['6ZQf9U-zoxo', 220.0, 230.0],
#  ['6nh77H89RzI', 0.0, 10.0],
#  ['6uhnFV4IByo', 30.0, 40.0],
#  ['6wAVcD4J1EE', 6.0, 16.0],
#  ['7-tA1tYeG7o', 230.0, 240.0],
#  ['72FjUmpsJyk', 29.0, 39.0],
#  ['7YyBddAnwHk', 30.0, 40.0],
#  ['7hdXzJpOXiY', 18.0, 28.0],
#  ['7k09T6S3i6k', 30.0, 40.0],
#  ['7kpYbTlXXp4', 30.0, 40.0],
#  ['7n2jhq-wi-Q', 7.0, 17.0],
#  ['8455AtIQh9k', 30.0, 40.0],
#  ['87Skd_EqUSw', 30.0, 40.0],
#  ['8UPK_6UGBVE', 320.0, 330.0],
#  ['8_o3kls-iL8', 30.0, 40.0],
#  ['8bERkwtKmMc', 2.0, 12.0],
#  ['8cMGBlj2bAk', 29.0, 39.0],
#  ['8l3ccRc_Ljw', 140.0, 150.0],
#  ['8weZUFLXNnE', 20.0, 30.0],
#  ['90177TPeR2g', 50.0, 60.0],
#  ['94oxhl9o4zc', 0.0, 10.0],
#  ['95T2WjyDhKk', 30.0, 40.0],
#  ['9H6FLDiM4gg', 30.0, 40.0],
#  ['9Vu4vPWZYJo', 30.0, 40.0],
#  ['9_DZ7TIm4sk', 30.0, 40.0],
#  ['9bhWKsM-FUs', 30.0, 40.0],
#  ['9dE8VuNgwYg', 18.0, 28.0],
#  ['9gCfNKhR3-g', 30.0, 40.0],
#  ['9wHXSPhnfcE', 30.0, 40.0],
#  ['9wkAMFbZkg4', 110.0, 120.0],
#  ['A1Q4fCL-TME', 260.0, 270.0],
#  ['AEalH0DM4iI', 17.0, 27.0],
#  ['AGoWSs94hQc', 30.0, 40.0],
#  ['APQZVq1pMsU', 180.0, 190.0],
#  ['ASZiqIOrZJo', 0.0, 10.0],
#  ['AcpuQrodb1k', 30.0, 40.0],
#  ['AogW-2HqvMo', 30.0, 40.0],
#  ['AtaCHP9YQIA', 30.0, 40.0],
#  ['AzUSK6jhnmM', 30.0, 40.0],
#  ['B6G0w_Bg5Nk', 70.0, 80.0],
#  ['BArGupQhId8', 30.0, 40.0],
#  ['BAtFJi6S-7c', 30.0, 40.0],
#  ['BDTlaUbJcrI', 30.0, 40.0],
#  ['BFuGVKI1wlA', 210.0, 220.0],
#  ['BKMle8hodOQ', 23.0, 33.0],
#  ['BLkx5dxHLl8', 30.0, 40.0],
#  ['BQQzUbV1tyQ', 20.0, 30.0],
#  ['C8Ne4NNA_CA', 10.0, 20.0],
#  ['CF9iqq99SOQ', 12.0, 22.0],
#  ['CMQArl9dSHY', 20.0, 30.0],
#  ['COGUADLm2gQ', 30.0, 40.0],
#  ['COt3JH5zlFI', 30.0, 40.0],
#  ['CagYyzDAHu0', 200.0, 210.0],
#  ['CdyHQN4MAPo', 10.0, 20.0],
#  ['Cefw_CgwGgM', 100.0, 110.0],
#  ['Czfg4OvI8ZE', 8.0, 18.0],
#  ['DIkSGraVUmk', 70.0, 80.0],
#  ['DKBrrRr5br4', 30.0, 40.0],
#  ['DaF5fZoz2jU', 30.0, 40.0],
#  ['DdGDeAFWlhA', 11.0, 21.0],
#  ['Dg1RaCMZTjM', 9.0, 19.0],
#  ['DlJ-i4oGkmI', 30.0, 40.0],
#  ['E23k1XhlmNQ', 0.0, 9.0],
#  ['E2AaojYhqrw', 15.0, 25.0],
#  ['E5XqPOzFnfI', 19.0, 29.0],
#  ['E6i9AKBYiKg', 2.0, 12.0],
#  ['E8e8vW7dH-E', 30.0, 40.0],
#  ['EF6duJ04-I4', 5.0, 15.0],
#  ['EFb39xJQwZ8', 0.0, 10.0],
#  ['EFsnLuj_ILM', 10.0, 20.0],
#  ['EGAGh17UgzM', 10.0, 20.0],
#  ['EH-uPC0U2-w', 0.0, 10.0],
#  ['EHr2Bjr155s', 40.0, 50.0],
#  ['EVQ5A56WWug', 30.0, 40.0],
#  ['EYqBcyK6q4U', 0.0, 9.0],
#  ['Eb0s6gKKFgs', 0.0, 9.0],
#  ['EhcdKAq3S8g', 20.0, 30.0],
#  ['EiWkTD26E-c', 170.0, 180.0],
#  ['Elg3q4FumgE', 10.0, 20.0],
#  ['EnxS29QYoSE', 0.0, 10.0],
#  ['ExQ-9F1dXGY', 90.0, 100.0],
#  ['F2-JvDbdWto', 30.0, 40.0],
#  ['FDkl-22SzfA', 6.0, 16.0],
#  ['FELMRwtte8c', 150.0, 160.0],
#  ['FMdxqkR9SQU', 50.0, 60.0],
#  ['FNRXerP9gyI', 10.0, 20.0],
#  ['FSt84_HGZSg', 20.0, 30.0],
#  ['FTxYiDvcp3c', 30.0, 40.0],
#  ['FudvpR9XTmw', 12.0, 22.0],
#  ['FuxDgrbnLkk', 30.0, 40.0],
#  ['FvYAC5A9e2M', 30.0, 40.0],
#  ['FvuVDLnhrwE', 13.0, 23.0],
#  ['G2E9YW83ak4', 30.0, 40.0],
#  ['G5Zk3PqFcVY', 20.0, 30.0],
#  ['G7IUTroCggA', 50.0, 60.0],
#  ['GPRfS66dF2A', 40.0, 50.0],
#  ['GPh_DShjdaA', 320.0, 330.0],
#  ['GWIoKdJwqDU', 9.0, 19.0],
#  ['GYx9Kkmj1Ks', 27.0, 37.0],
#  ['GbyK-4HCwUE', 240.0, 250.0],
#  ['GcOAQUWJOOQ', 0.0, 9.0],
#  ['GgjpbZbacIs', 30.0, 40.0],
#  ['GzZrQR5VMwA', 30.0, 40.0],
#  ['H3LNRMSZX4s', 30.0, 40.0],
#  ['H5MRGb0ndog', 30.0, 40.0],
#  ['HEg1bmaRqlA', 30.0, 40.0],
#  ['HFTfES3CBI0', 7.0, 17.0],
#  ['HHI2bGHyM0o', 30.0, 40.0],
#  ['HQQxGJKg1iM', 30.0, 40.0],
#  ['Hpnja1gcKN0', 30.0, 40.0],
#  ['I-rxfgLegBU', 30.0, 40.0],
#  ['I3oeJ3tAnxE', 30.0, 40.0],
#  ['I7fdphE2vRM', 200.0, 210.0],
#  ['IA7HA1NMPGg', 40.0, 50.0],
#  ['ITQNxkJrqOk', 30.0, 40.0],
#  ['IX-EAGiSw1I', 30.0, 40.0],
#  ['IieMyEQ9wcU', 90.0, 100.0],
#  ['IoIF17NdNiQ', 60.0, 70.0],
#  ['ItmS1mhB78o', 0.0, 10.0],
#  ['Iyyrm16i22w', 30.0, 40.0],
#  ['J3blNOPsCEo', 0.0, 10.0],
#  ['J4GgFgjpbuQ', 4.0, 14.0],
#  ['J7DeQFyq6Eg', 10.0, 20.0],
#  ['JSBJwIUC8UM', 160.0, 170.0],
#  ['JTblOMoHXOg', 30.0, 40.0],
#  ['JVwyUXIMxcc', 0.0, 10.0],
#  ['JZlsCt8YVIA', 0.0, 10.0],
#  ['JcO2TTtiplA', 30.0, 40.0],
#  ['JdIfNzA9ksY', 50.0, 60.0],
#  ['JeKPdLYffsI', 30.0, 40.0],
#  ['JfzM_99kuTU', 0.0, 10.0],
#  ['JsF0cyKD0UQ', 430.0, 440.0],
#  ['K9lmiWhXu1s', 0.0, 9.0],
#  ['KHvh_9Pu0sY', 90.0, 100.0],
#  ['KJT7O8VkOZ8', 22.0, 32.0],
#  ['KYyCfsJYQM4', 470.0, 480.0],
#  ['Kdoepth5luc', 26.0, 36.0],
#  ['Ktrc4jjT0QU', 30.0, 40.0],
#  ['Kz91IHNxA8U', 0.0, 10.0],
#  ['L19iNwKlzk0', 50.0, 60.0],
#  ['L4XjN9ixl1M', 15.0, 25.0],
#  ['LMpxEF4Ag7M', 180.0, 190.0],
#  ['LcdryGfdpNI', 17.0, 27.0],
#  ['LjHOYz7q1YQ', 180.0, 190.0],
#  ['Ln8NGg3Ll5o', 5.0, 15.0],
#  ['Lp8ahrjqnbM', 0.0, 10.0],
#  ['LroT8c4qWlM', 30.0, 40.0],
#  ['Ls_8qHsZZ5E', 30.0, 40.0],
#  ['LwdF3e2oFow', 6.0, 16.0],
#  ['M5uXEctVuEY', 30.0, 40.0],
#  ['M7mIQuPV_t0', 17.0, 27.0],
#  ['MFAmvXBkhTs', 30.0, 40.0],
#  ['MJ-wuiqNzv0', 0.0, 10.0],
#  ['MYBtLHrvcTU', 30.0, 40.0],
#  ['Mtt9SYVvw6k', 30.0, 40.0],
#  ['N0qy-eVVw64', 30.0, 40.0],
#  ['N8pp9lClzRc', 60.0, 70.0],
#  ['NF2HCvevKEk', 30.0, 40.0],
#  ['NGIwHTuX9HA', 30.0, 40.0],
#  ['NJHxX-r5oHE', 30.0, 40.0],
#  ['NQ0PRMb-g24', 30.0, 40.0],
#  ['NUk1K03uxnI', 30.0, 40.0],
#  ['NVuxT7-9fb8', 5.0, 15.0],
#  ['NZ8pS8fv7Q8', 20.0, 30.0],
#  ['N_GeH99AiVY', 30.0, 40.0],
#  ['NmiI8PtyieE', 10.0, 20.0],
#  ['NmsYPXUJzVY', 30.0, 40.0],
#  ['NsRmoJKZomw', 30.0, 40.0],
#  ['NvlghYdEJeQ', 40.0, 50.0],
#  ['Nwd8GcEeQCU', 30.0, 40.0],
#  ['O3geFV-GoqM', 0.0, 10.0],
#  ['O4uv0JJTVzw', 3.0, 13.0],
#  ['OA0rZOi8Kx8', 0.0, 8.0],
#  ['OEvOWZWr9D8', 30.0, 40.0],
#  ['OJobEDITPZo', 30.0, 40.0],
#  ['OK_3NWWadT0', 1.0, 11.0],
#  ['ORSvarz5uWk', 30.0, 40.0],
#  ['ORivJXXSxqc', 0.0, 10.0],
#  ['OaoEyjfCPak', 0.0, 10.0],
#  ['P3-jB8vi-no', 110.0, 120.0]]

# %%
print(np.array(temp_police).shape)
# Out:
# (242, 3)

# %%
for j in range(1,4):
    x=temp_police.pop(j)

# %%
temp_police.pop(1)
# Out:
# ['#NAME?', 10.0, 20.0]

# %%
temp_police
# Out:
# [['-122tCXtFhU', 30.0, 40.0],
#  ['09dzay_jgNs', 30.0, 40.0],
#  ['0I6Mlp27_gM', 30.0, 40.0],
#  ['0Y98tzWJkjw', 140.0, 150.0],
#  ['0rKDe5UNSlk', 30.0, 40.0],
#  ['0xbnKT0lTZY', 7.0, 17.0],
#  ['12K4PFm6afY', 0.0, 10.0],
#  ['12aXUfObwlY', 0.0, 10.0],
#  ['1NVfl7AnSRg', 30.0, 40.0],
#  ['1PPn02f5M2U', 3.0, 13.0],
#  ['1W-yspM_mns', 30.0, 40.0],
#  ['1XPr0mGp4JI', 30.0, 40.0],
#  ['1Y-X9sA1V0w', 30.0, 40.0],
#  ['1Yxm08Q5j04', 14.0, 24.0],
#  ['1aXQVJWpgKQ', 30.0, 40.0],
#  ['1menriOu8xI', 10.0, 20.0],
#  ['1pLOAHXZTdQ', 0.0, 10.0],
#  ['1tdGqmmMvN8', 30.0, 40.0],
#  ['1wxDPv-U7XI', 20.0, 30.0],
#  ['1z1x1KrGWVw', 150.0, 160.0],
#  ['20QEXBty5iY', 27.0, 37.0],
#  ['256ESX-Fe90', 30.0, 40.0],
#  ['2DC5uZcrhcY', 10.0, 20.0],
#  ['2MHhtDe72Sc', 50.0, 60.0],
#  ['2NU-ij1hO2c', 30.0, 40.0],
#  ['2NlASv1Z5IY', 30.0, 40.0],
#  ['2S3bd7jBX0Q', 10.0, 20.0],
#  ['2fS6PbFGVKw', 25.0, 35.0],
#  ['2jXPc6IC1zE', 20.0, 30.0],
#  ['2xWH7McfIVA', 50.0, 60.0],
#  ['2zusC8gWnXw', 24.0, 34.0],
#  ['35t3MVCE160', 30.0, 40.0],
#  ['3T1z1c3Z_Es', 40.0, 50.0],
#  ['3UE_AQZ9RNU', 30.0, 40.0],
#  ['3gJkDVFdBSc', 30.0, 40.0],
#  ['3jEK-hQZshU', 0.0, 10.0],
#  ['3sVWGc8Z7F4', 30.0, 40.0],
#  ['447Tv2wYwR0', 21.0, 31.0],
#  ['495SjWHEz7Q', 25.0, 35.0],
#  ['4vdEmK_Ywhs', 30.0, 40.0],
#  ['50UkIXNt9M8', 30.0, 40.0],
#  ['57NefYJLTE4', 30.0, 40.0],
#  ['5EueOObOVGw', 16.0, 26.0],
#  ['5UEANjv4EaQ', 3.0, 13.0],
#  ['5XkYYom37u0', 7.0, 17.0],
#  ['5_6WkhNqyN4', 4.0, 14.0],
#  ['5eNOKWmmCcI', 30.0, 40.0],
#  ['5om-tsbyY9M', 0.0, 10.0],
#  ['5p-XAJdzqPc', 30.0, 40.0],
#  ['5sicVdGVYco', 30.0, 40.0],
#  ['5tb_c-jFqMw', 30.0, 40.0],
#  ['5z-qZv3F2V0', 200.0, 210.0],
#  ['6GJY_1ThSNY', 23.0, 33.0],
#  ['6HqoI_24yE4', 40.0, 50.0],
#  ['6ZQf9U-zoxo', 220.0, 230.0],
#  ['6nh77H89RzI', 0.0, 10.0],
#  ['6uhnFV4IByo', 30.0, 40.0],
#  ['6wAVcD4J1EE', 6.0, 16.0],
#  ['7-tA1tYeG7o', 230.0, 240.0],
#  ['72FjUmpsJyk', 29.0, 39.0],
#  ['7YyBddAnwHk', 30.0, 40.0],
#  ['7hdXzJpOXiY', 18.0, 28.0],
#  ['7k09T6S3i6k', 30.0, 40.0],
#  ['7kpYbTlXXp4', 30.0, 40.0],
#  ['7n2jhq-wi-Q', 7.0, 17.0],
#  ['8455AtIQh9k', 30.0, 40.0],
#  ['87Skd_EqUSw', 30.0, 40.0],
#  ['8UPK_6UGBVE', 320.0, 330.0],
#  ['8_o3kls-iL8', 30.0, 40.0],
#  ['8bERkwtKmMc', 2.0, 12.0],
#  ['8cMGBlj2bAk', 29.0, 39.0],
#  ['8l3ccRc_Ljw', 140.0, 150.0],
#  ['8weZUFLXNnE', 20.0, 30.0],
#  ['90177TPeR2g', 50.0, 60.0],
#  ['94oxhl9o4zc', 0.0, 10.0],
#  ['95T2WjyDhKk', 30.0, 40.0],
#  ['9H6FLDiM4gg', 30.0, 40.0],
#  ['9Vu4vPWZYJo', 30.0, 40.0],
#  ['9_DZ7TIm4sk', 30.0, 40.0],
#  ['9bhWKsM-FUs', 30.0, 40.0],
#  ['9dE8VuNgwYg', 18.0, 28.0],
#  ['9gCfNKhR3-g', 30.0, 40.0],
#  ['9wHXSPhnfcE', 30.0, 40.0],
#  ['9wkAMFbZkg4', 110.0, 120.0],
#  ['A1Q4fCL-TME', 260.0, 270.0],
#  ['AEalH0DM4iI', 17.0, 27.0],
#  ['AGoWSs94hQc', 30.0, 40.0],
#  ['APQZVq1pMsU', 180.0, 190.0],
#  ['ASZiqIOrZJo', 0.0, 10.0],
#  ['AcpuQrodb1k', 30.0, 40.0],
#  ['AogW-2HqvMo', 30.0, 40.0],
#  ['AtaCHP9YQIA', 30.0, 40.0],
#  ['AzUSK6jhnmM', 30.0, 40.0],
#  ['B6G0w_Bg5Nk', 70.0, 80.0],
#  ['BArGupQhId8', 30.0, 40.0],
#  ['BAtFJi6S-7c', 30.0, 40.0],
#  ['BDTlaUbJcrI', 30.0, 40.0],
#  ['BFuGVKI1wlA', 210.0, 220.0],
#  ['BKMle8hodOQ', 23.0, 33.0],
#  ['BLkx5dxHLl8', 30.0, 40.0],
#  ['BQQzUbV1tyQ', 20.0, 30.0],
#  ['C8Ne4NNA_CA', 10.0, 20.0],
#  ['CF9iqq99SOQ', 12.0, 22.0],
#  ['CMQArl9dSHY', 20.0, 30.0],
#  ['COGUADLm2gQ', 30.0, 40.0],
#  ['COt3JH5zlFI', 30.0, 40.0],
#  ['CagYyzDAHu0', 200.0, 210.0],
#  ['CdyHQN4MAPo', 10.0, 20.0],
#  ['Cefw_CgwGgM', 100.0, 110.0],
#  ['Czfg4OvI8ZE', 8.0, 18.0],
#  ['DIkSGraVUmk', 70.0, 80.0],
#  ['DKBrrRr5br4', 30.0, 40.0],
#  ['DaF5fZoz2jU', 30.0, 40.0],
#  ['DdGDeAFWlhA', 11.0, 21.0],
#  ['Dg1RaCMZTjM', 9.0, 19.0],
#  ['DlJ-i4oGkmI', 30.0, 40.0],
#  ['E23k1XhlmNQ', 0.0, 9.0],
#  ['E2AaojYhqrw', 15.0, 25.0],
#  ['E5XqPOzFnfI', 19.0, 29.0],
#  ['E6i9AKBYiKg', 2.0, 12.0],
#  ['E8e8vW7dH-E', 30.0, 40.0],
#  ['EF6duJ04-I4', 5.0, 15.0],
#  ['EFb39xJQwZ8', 0.0, 10.0],
#  ['EFsnLuj_ILM', 10.0, 20.0],
#  ['EGAGh17UgzM', 10.0, 20.0],
#  ['EH-uPC0U2-w', 0.0, 10.0],
#  ['EHr2Bjr155s', 40.0, 50.0],
#  ['EVQ5A56WWug', 30.0, 40.0],
#  ['EYqBcyK6q4U', 0.0, 9.0],
#  ['Eb0s6gKKFgs', 0.0, 9.0],
#  ['EhcdKAq3S8g', 20.0, 30.0],
#  ['EiWkTD26E-c', 170.0, 180.0],
#  ['Elg3q4FumgE', 10.0, 20.0],
#  ['EnxS29QYoSE', 0.0, 10.0],
#  ['ExQ-9F1dXGY', 90.0, 100.0],
#  ['F2-JvDbdWto', 30.0, 40.0],
#  ['FDkl-22SzfA', 6.0, 16.0],
#  ['FELMRwtte8c', 150.0, 160.0],
#  ['FMdxqkR9SQU', 50.0, 60.0],
#  ['FNRXerP9gyI', 10.0, 20.0],
#  ['FSt84_HGZSg', 20.0, 30.0],
#  ['FTxYiDvcp3c', 30.0, 40.0],
#  ['FudvpR9XTmw', 12.0, 22.0],
#  ['FuxDgrbnLkk', 30.0, 40.0],
#  ['FvYAC5A9e2M', 30.0, 40.0],
#  ['FvuVDLnhrwE', 13.0, 23.0],
#  ['G2E9YW83ak4', 30.0, 40.0],
#  ['G5Zk3PqFcVY', 20.0, 30.0],
#  ['G7IUTroCggA', 50.0, 60.0],
#  ['GPRfS66dF2A', 40.0, 50.0],
#  ['GPh_DShjdaA', 320.0, 330.0],
#  ['GWIoKdJwqDU', 9.0, 19.0],
#  ['GYx9Kkmj1Ks', 27.0, 37.0],
#  ['GbyK-4HCwUE', 240.0, 250.0],
#  ['GcOAQUWJOOQ', 0.0, 9.0],
#  ['GgjpbZbacIs', 30.0, 40.0],
#  ['GzZrQR5VMwA', 30.0, 40.0],
#  ['H3LNRMSZX4s', 30.0, 40.0],
#  ['H5MRGb0ndog', 30.0, 40.0],
#  ['HEg1bmaRqlA', 30.0, 40.0],
#  ['HFTfES3CBI0', 7.0, 17.0],
#  ['HHI2bGHyM0o', 30.0, 40.0],
#  ['HQQxGJKg1iM', 30.0, 40.0],
#  ['Hpnja1gcKN0', 30.0, 40.0],
#  ['I-rxfgLegBU', 30.0, 40.0],
#  ['I3oeJ3tAnxE', 30.0, 40.0],
#  ['I7fdphE2vRM', 200.0, 210.0],
#  ['IA7HA1NMPGg', 40.0, 50.0],
#  ['ITQNxkJrqOk', 30.0, 40.0],
#  ['IX-EAGiSw1I', 30.0, 40.0],
#  ['IieMyEQ9wcU', 90.0, 100.0],
#  ['IoIF17NdNiQ', 60.0, 70.0],
#  ['ItmS1mhB78o', 0.0, 10.0],
#  ['Iyyrm16i22w', 30.0, 40.0],
#  ['J3blNOPsCEo', 0.0, 10.0],
#  ['J4GgFgjpbuQ', 4.0, 14.0],
#  ['J7DeQFyq6Eg', 10.0, 20.0],
#  ['JSBJwIUC8UM', 160.0, 170.0],
#  ['JTblOMoHXOg', 30.0, 40.0],
#  ['JVwyUXIMxcc', 0.0, 10.0],
#  ['JZlsCt8YVIA', 0.0, 10.0],
#  ['JcO2TTtiplA', 30.0, 40.0],
#  ['JdIfNzA9ksY', 50.0, 60.0],
#  ['JeKPdLYffsI', 30.0, 40.0],
#  ['JfzM_99kuTU', 0.0, 10.0],
#  ['JsF0cyKD0UQ', 430.0, 440.0],
#  ['K9lmiWhXu1s', 0.0, 9.0],
#  ['KHvh_9Pu0sY', 90.0, 100.0],
#  ['KJT7O8VkOZ8', 22.0, 32.0],
#  ['KYyCfsJYQM4', 470.0, 480.0],
#  ['Kdoepth5luc', 26.0, 36.0],
#  ['Ktrc4jjT0QU', 30.0, 40.0],
#  ['Kz91IHNxA8U', 0.0, 10.0],
#  ['L19iNwKlzk0', 50.0, 60.0],
#  ['L4XjN9ixl1M', 15.0, 25.0],
#  ['LMpxEF4Ag7M', 180.0, 190.0],
#  ['LcdryGfdpNI', 17.0, 27.0],
#  ['LjHOYz7q1YQ', 180.0, 190.0],
#  ['Ln8NGg3Ll5o', 5.0, 15.0],
#  ['Lp8ahrjqnbM', 0.0, 10.0],
#  ['LroT8c4qWlM', 30.0, 40.0],
#  ['Ls_8qHsZZ5E', 30.0, 40.0],
#  ['LwdF3e2oFow', 6.0, 16.0],
#  ['M5uXEctVuEY', 30.0, 40.0],
#  ['M7mIQuPV_t0', 17.0, 27.0],
#  ['MFAmvXBkhTs', 30.0, 40.0],
#  ['MJ-wuiqNzv0', 0.0, 10.0],
#  ['MYBtLHrvcTU', 30.0, 40.0],
#  ['Mtt9SYVvw6k', 30.0, 40.0],
#  ['N0qy-eVVw64', 30.0, 40.0],
#  ['N8pp9lClzRc', 60.0, 70.0],
#  ['NF2HCvevKEk', 30.0, 40.0],
#  ['NGIwHTuX9HA', 30.0, 40.0],
#  ['NJHxX-r5oHE', 30.0, 40.0],
#  ['NQ0PRMb-g24', 30.0, 40.0],
#  ['NUk1K03uxnI', 30.0, 40.0],
#  ['NVuxT7-9fb8', 5.0, 15.0],
#  ['NZ8pS8fv7Q8', 20.0, 30.0],
#  ['N_GeH99AiVY', 30.0, 40.0],
#  ['NmiI8PtyieE', 10.0, 20.0],
#  ['NmsYPXUJzVY', 30.0, 40.0],
#  ['NsRmoJKZomw', 30.0, 40.0],
#  ['NvlghYdEJeQ', 40.0, 50.0],
#  ['Nwd8GcEeQCU', 30.0, 40.0],
#  ['O3geFV-GoqM', 0.0, 10.0],
#  ['O4uv0JJTVzw', 3.0, 13.0],
#  ['OA0rZOi8Kx8', 0.0, 8.0],
#  ['OEvOWZWr9D8', 30.0, 40.0],
#  ['OJobEDITPZo', 30.0, 40.0],
#  ['OK_3NWWadT0', 1.0, 11.0],
#  ['ORSvarz5uWk', 30.0, 40.0],
#  ['ORivJXXSxqc', 0.0, 10.0],
#  ['OaoEyjfCPak', 0.0, 10.0],
#  ['P3-jB8vi-no', 110.0, 120.0]]

# %%
print(np.array(temp_police).shape)
# Out:
# (234, 3)

# %%
print(np.array(police_lst).shape)
# Out:
# (234, 3)

# %%
for i in range(np.array(police_lst).shape[0]):
    try:
        ts=police_lst[i][1]
        te=police_lst[i][2]
        #print(te,ts)
        y_id=police_lst[i][0]
        video_url='https://www.youtube.com/watch?v={}'.format(y_id)
        video=pafy.new(video_url)
        best_audio=video.getbestaudio()
        audio_name=best_audio.filename
        best_audio.download()
        if os.path.exists(audio_name):
            output_file='Police_'+str(i)+'.webm'
            ffmpeg_extract_subclip(audio_name,ts,te,targetname=output_file)
            os.remove(audio_name)
        print("DONE FOR {}".format(i))
    except:
        print('Error in file : '.format(i+1))
# Out:
#   659,094.0 Bytes [100.00%] received. Rate: [5422 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 0
#   6,452,455.0 Bytes [100.00%] received. Rate: [17117 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 1
#   6,223,188.0 Bytes [100.00%] received. Rate: [14849 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 2
#   2,378,366.0 Bytes [100.00%] received. Rate: [3204 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 3
#   6,938,748.0 Bytes [100.00%] received. Rate: [18387 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 4
#   16,384.0 Bytes [100.00%] received. Rate: [1003 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file :
#   255,961.0 Bytes [100.00%] received. Rate: [ 630 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 7
#   2,204,499.0 Bytes [100.00%] received. Rate: [2624 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 8
#   17,745.0 Bytes [100.00%] received. Rate: [ 967 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
# Error in file :
#   1,160,617.0 Bytes [100.00%] received. Rate: [1939 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 11
#   33,377.0 Bytes [100.00%] received. Rate: [ 960 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   9,780.0 Bytes [100.00%] received. Rate: [1605 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   712,749.0 Bytes [100.00%] received. Rate: [1304 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 14
#   7,559,525.0 Bytes [100.00%] received. Rate: [1905 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 15
#   198,360.0 Bytes [100.00%] received. Rate: [1923 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 16
#   2,218,115.0 Bytes [100.00%] received. Rate: [6366 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 17
#   2,265,078.0 Bytes [100.00%] received. Rate: [1592 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 18
#   1,465,183.0 Bytes [100.00%] received. Rate: [2274 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 19
#   646,590.0 Bytes [100.00%] received. Rate: [1738 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 20
#   1,576,372.0 Bytes [100.00%] received. Rate: [2357 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 21
#   290,810.0 Bytes [100.00%] received. Rate: [ 771 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 22
#   1,524,235.0 Bytes [100.00%] received. Rate: [4645 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 23
#   1,249,666.0 Bytes [100.00%] received. Rate: [4172 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 24
#   8,672,391.0 Bytes [100.00%] received. Rate: [8157 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 25
# ERROR: This video is no longer available due to a copyright claim by rnickeymouse.
# Sorry about that.
# Error in file :
#   666,190.0 Bytes [100.00%] received. Rate: [1237 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 27
#   984,578.0 Bytes [100.00%] received. Rate: [1673 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 28
#   1,266,772.0 Bytes [100.00%] received. Rate: [1856 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 29
#   452,925.0 Bytes [100.00%] received. Rate: [ 911 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 30
#   2,099,615.0 Bytes [100.00%] received. Rate: [2151 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 31
#   17,016.0 Bytes [100.00%] received. Rate: [ 980 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   24,570.0 Bytes [100.00%] received. Rate: [1044 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   783,920.0 Bytes [100.00%] received. Rate: [3411 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 34
#   1,369,899.0 Bytes [100.00%] received. Rate: [4314 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 35
#   17,327,462.0 Bytes [100.00%] received. Rate: [ 926 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 36
#   434,465.0 Bytes [100.00%] received. Rate: [ 939 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 37
#   15,049.0 Bytes [100.00%] received. Rate: [1134 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   1,375,032.0 Bytes [100.00%] received. Rate: [2192 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 39
#   619,888.0 Bytes [100.00%] received. Rate: [1136 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 40
#   792,356.0 Bytes [100.00%] received. Rate: [1360 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 41
#   399,331.0 Bytes [100.00%] received. Rate: [2300 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 42
#   196,072.0 Bytes [100.00%] received. Rate: [ 602 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 43
#   184,121.0 Bytes [100.00%] received. Rate: [2043 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 44
#   185,118.0 Bytes [100.00%] received. Rate: [ 579 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 45
#   44,788,818.0 Bytes [100.00%] received. Rate: [1953 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 46
#   4,277,120.0 Bytes [100.00%] received. Rate: [2410 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 47
#   5,914,685.0 Bytes [100.00%] received. Rate: [3410 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 48
#   27,037.0 Bytes [100.00%] received. Rate: [1059 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   538,180.0 Bytes [100.00%] received. Rate: [1017 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 50
#   7,108,284.0 Bytes [100.00%] received. Rate: [2387 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 51
#   526,399.0 Bytes [100.00%] received. Rate: [1015 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 52
#   932,278.0 Bytes [100.00%] received. Rate: [1708 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 53
#   4,521,232.0 Bytes [100.00%] received. Rate: [4759 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 54
#   1,106,904.0 Bytes [100.00%] received. Rate: [1836 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 55
#   2,196,079.0 Bytes [100.00%] received. Rate: [2702 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 56
#   211,613.0 Bytes [100.00%] received. Rate: [ 611 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 57
#   6,486,600.0 Bytes [100.00%] received. Rate: [5930 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 58
#   614,926.0 Bytes [100.00%] received. Rate: [2611 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 59
#   7,627,463.0 Bytes [100.00%] received. Rate: [3874 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 60
#   593,116.0 Bytes [100.00%] received. Rate: [1169 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 61
#   1,052,922.0 Bytes [100.00%] received. Rate: [1032 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 62
#   2,175,707.0 Bytes [100.00%] received. Rate: [3103 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 63
#   272,915.0 Bytes [100.00%] received. Rate: [ 713 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 64
#   2,643,760.0 Bytes [100.00%] received. Rate: [2570 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 65
#   767,019.0 Bytes [100.00%] received. Rate: [1382 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 66
#   6,319,176.0 Bytes [100.00%] received. Rate: [2979 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 67
#   5,126,249.0 Bytes [100.00%] received. Rate: [2865 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 68
#   144,910.0 Bytes [100.00%] received. Rate: [ 500 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 69
#   722,484.0 Bytes [100.00%] received. Rate: [1285 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 70
#   25,601.0 Bytes [100.00%] received. Rate: [1044 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   787,905.0 Bytes [100.00%] received. Rate: [1437 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 72
#   66,579.0 Bytes [100.00%] received. Rate: [ 471 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   140,453.0 Bytes [100.00%] received. Rate: [2149 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 74
#   2,356,399.0 Bytes [100.00%] received. Rate: [2812 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 75
#   24,701.0 Bytes [100.00%] received. Rate: [1344 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   2,679,341.0 Bytes [100.00%] received. Rate: [2876 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 77
#   1,152,996.0 Bytes [100.00%] received. Rate: [1764 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 78
#   21,812,608.0 Bytes [100.00%] received. Rate: [1304 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 79
#   373,485.0 Bytes [100.00%] received. Rate: [2151 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 80
#   1,047,239.0 Bytes [100.00%] received. Rate: [6056 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 81
#   3,754,536.0 Bytes [100.00%] received. Rate: [3232 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 82
#   2,775,581.0 Bytes [100.00%] received. Rate: [3165 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 83
#   11,913,638.0 Bytes [100.00%] received. Rate: [1983 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 84
#   193,922.0 Bytes [100.00%] received. Rate: [ 589 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 85
#   586,476.0 Bytes [100.00%] received. Rate: [1154 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 86
#   47,720.0 Bytes [100.00%] received. Rate: [ 630 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   2,963,011.0 Bytes [100.00%] received. Rate: [1758 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 88
#   3,314,579.0 Bytes [100.00%] received. Rate: [5589 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 89
#   1,312,738.0 Bytes [100.00%] received. Rate: [2015 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 90
#   5,300,687.0 Bytes [100.00%] received. Rate: [3698 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 91
#   882,749.0 Bytes [100.00%] received. Rate: [1503 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 92
#   1,368,263.0 Bytes [100.00%] received. Rate: [2104 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 93
#   1,086,860.0 Bytes [100.00%] received. Rate: [1720 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 94
#   23,491,677.0 Bytes [100.00%] received. Rate: [3365 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 95
#   13,516.0 Bytes [100.00%] received. Rate: [1104 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   4,542,133.0 Bytes [100.00%] received. Rate: [2389 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 97
#   477,349.0 Bytes [100.00%] received. Rate: [ 946 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 98
# ERROR: Content Warning
# If the owner of this video has granted you access, please sign in.
#        This video is private.
# Error in file :
#   720,160.0 Bytes [100.00%] received. Rate: [3023 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 100
#   410,011.0 Bytes [100.00%] received. Rate: [4056 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 101
#   259,207.0 Bytes [100.00%] received. Rate: [ 709 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 102
#   907,456.0 Bytes [100.00%] received. Rate: [1600 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 103
#   9,571,855.0 Bytes [100.00%] received. Rate: [3320 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 104
#   907,039.0 Bytes [100.00%] received. Rate: [1567 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 105
#   7,375,800.0 Bytes [100.00%] received. Rate: [17864 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 106
#   1,102,445.0 Bytes [100.00%] received. Rate: [4134 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 107
#   3,390,275.0 Bytes [100.00%] received. Rate: [4175 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 108
#   287,515.0 Bytes [100.00%] received. Rate: [ 758 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 109
#   10,967,756.0 Bytes [100.00%] received. Rate: [1020 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 110
#   1,212,027.0 Bytes [100.00%] received. Rate: [1870 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 111
#   3,313,894.0 Bytes [100.00%] received. Rate: [2393 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 112
#   396,336.0 Bytes [100.00%] received. Rate: [1283 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 113
#   326,002.0 Bytes [100.00%] received. Rate: [ 784 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 114
#   874,808.0 Bytes [100.00%] received. Rate: [1494 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 115
#   143,922.0 Bytes [100.00%] received. Rate: [ 491 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 116
#   14,346.0 Bytes [100.00%] received. Rate: [1170 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   17,324.0 Bytes [100.00%] received. Rate: [ 998 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
# ERROR: This video is no longer available because the YouTube account associated with this video has been terminated.
# Sorry about that.
# Error in file :
#   1,262,788.0 Bytes [100.00%] received. Rate: [3793 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 120
#   216,537.0 Bytes [100.00%] received. Rate: [ 612 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 121
#   426,218.0 Bytes [100.00%] received. Rate: [2303 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 122
#   252,439.0 Bytes [100.00%] received. Rate: [ 683 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 123
#   834,188.0 Bytes [100.00%] received. Rate: [2018 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 124
#   786,105.0 Bytes [100.00%] received. Rate: [1378 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 125
#   28,133.0 Bytes [100.00%] received. Rate: [1060 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   30,405.0 Bytes [100.00%] received. Rate: [1297 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   166,780.0 Bytes [100.00%] received. Rate: [ 545 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 128
#   8,906.0 Bytes [100.00%] received. Rate: [ 674 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   1,303,447.0 Bytes [100.00%] received. Rate: [2085 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 130
#   6,499,491.0 Bytes [100.00%] received. Rate: [2649 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 131
#   696,545.0 Bytes [100.00%] received. Rate: [1257 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 132
#   400,853.0 Bytes [100.00%] received. Rate: [4267 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 133
#   3,086,415.0 Bytes [100.00%] received. Rate: [1249 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 134
#   779,940.0 Bytes [100.00%] received. Rate: [1078 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 135
#   180,430.0 Bytes [100.00%] received. Rate: [ 569 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 136
#   5,106,309.0 Bytes [100.00%] received. Rate: [5543 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 137
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file :
#   656,154.0 Bytes [100.00%] received. Rate: [1201 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 139
#   75,349.0 Bytes [100.00%] received. Rate: [ 535 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   21,373.0 Bytes [100.00%] received. Rate: [ 954 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   424,590.0 Bytes [100.00%] received. Rate: [ 908 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 142
#   795,700.0 Bytes [100.00%] received. Rate: [2910 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 143
#   786,608.0 Bytes [100.00%] received. Rate: [1390 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 144
#   332,559.0 Bytes [100.00%] received. Rate: [ 815 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 145
#   630,641.0 Bytes [100.00%] received. Rate: [1213 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 146
#   3,245,272.0 Bytes [100.00%] received. Rate: [4334 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 147
#   1,028,273.0 Bytes [100.00%] received. Rate: [1705 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 148
#   1,884,871.0 Bytes [100.00%] received. Rate: [2745 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 149
#   5,274,160.0 Bytes [100.00%] received. Rate: [2482 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 150
#   347,384.0 Bytes [100.00%] received. Rate: [ 810 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 151
#   565,234.0 Bytes [100.00%] received. Rate: [1109 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 152
#   20,791,519.0 Bytes [100.00%] received. Rate: [5354 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 153
#   128,205.0 Bytes [100.00%] received. Rate: [ 473 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 154
#   733,078.0 Bytes [100.00%] received. Rate: [3148 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 155
#   2,898,600.0 Bytes [100.00%] received. Rate: [3029 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 156
#   1,162,479.0 Bytes [100.00%] received. Rate: [1934 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 157
#   2,662,062.0 Bytes [100.00%] received. Rate: [2151 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 158
#   603,587.0 Bytes [100.00%] received. Rate: [5325 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 159
#   19,803.0 Bytes [100.00%] received. Rate: [1019 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file :
#   1,005,207.0 Bytes [100.00%] received. Rate: [1677 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 162
#   5,027,251.0 Bytes [100.00%] received. Rate: [2375 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 163
#   1,076,237.0 Bytes [100.00%] received. Rate: [6880 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 164
#   4,823,814.0 Bytes [100.00%] received. Rate: [2581 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 165
#   37,537.0 Bytes [100.00%] received. Rate: [ 994 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   778,528.0 Bytes [100.00%] received. Rate: [1394 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 167
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file :
#   871,201.0 Bytes [100.00%] received. Rate: [1480 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 169
#   26,124.0 Bytes [100.00%] received. Rate: [1161 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   4,171,449.0 Bytes [100.00%] received. Rate: [2999 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 171
#   612,904.0 Bytes [100.00%] received. Rate: [1129 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 172
#   29,696.0 Bytes [100.00%] received. Rate: [1077 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   207,294.0 Bytes [100.00%] received. Rate: [ 613 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 174
#   215,796.0 Bytes [100.00%] received. Rate: [ 622 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 175
#   296,630.0 Bytes [100.00%] received. Rate: [ 768 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 176
#   19,400.0 Bytes [100.00%] received. Rate: [ 905 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   593,587.0 Bytes [100.00%] received. Rate: [1123 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 178
#   17,415.0 Bytes [100.00%] received. Rate: [ 851 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   1,581,114.0 Bytes [100.00%] received. Rate: [1939 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 180
#   496,455.0 Bytes [100.00%] received. Rate: [ 985 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 181
#   3,628,824.0 Bytes [100.00%] received. Rate: [4274 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 182
#   1,442,163.0 Bytes [100.00%] received. Rate: [2000 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 183
#   249,096.0 Bytes [100.00%] received. Rate: [ 689 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 184
# ERROR: This video is no longer available due to a copyright claim by Aiplex Software Pvt Ltd.
# Sorry about that.
# Error in file :
#   118,394.0 Bytes [100.00%] received. Rate: [ 410 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 186
# ERROR: Content Warning
# If the owner of this video has granted you access, please sign in.
#        This video is private.
# Error in file :
#   394,131.0 Bytes [100.00%] received. Rate: [ 856 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 188
#   8,447,370.0 Bytes [100.00%] received. Rate: [6046 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 189
#   665,477.0 Bytes [100.00%] received. Rate: [1114 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 190
#   829,802.0 Bytes [100.00%] received. Rate: [1451 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 191
#   866,713.0 Bytes [100.00%] received. Rate: [3042 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 192
#   1,434,281.0 Bytes [100.00%] received. Rate: [2393 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 193
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file :
#   5,222,091.0 Bytes [100.00%] received. Rate: [2938 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 195
#   311,895.0 Bytes [100.00%] received. Rate: [ 799 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 196
#   3,074,567.0 Bytes [100.00%] received. Rate: [3684 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 197
#   231,327.0 Bytes [100.00%] received. Rate: [2058 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 198
#   2,534,587.0 Bytes [100.00%] received. Rate: [3352 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 199
#   20,962.0 Bytes [100.00%] received. Rate: [1141 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   35,231.0 Bytes [100.00%] received. Rate: [ 977 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   182,907.0 Bytes [100.00%] received. Rate: [1456 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 202
#   7,790,696.0 Bytes [100.00%] received. Rate: [7082 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 203
#   344,488.0 Bytes [100.00%] received. Rate: [1076 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 204
#   2,049,088.0 Bytes [100.00%] received. Rate: [7815 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 205
#   9,835.0 Bytes [100.00%] received. Rate: [ 963 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   1,694,840.0 Bytes [100.00%] received. Rate: [2338 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 207
#   2,311,194.0 Bytes [100.00%] received. Rate: [2523 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 208
#   515,251.0 Bytes [100.00%] received. Rate: [ 938 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   1,716,532.0 Bytes [100.00%] received. Rate: [2313 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 210
#   19,567.0 Bytes [100.00%] received. Rate: [1064 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   2,039,298.0 Bytes [100.00%] received. Rate: [2714 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 212
#   2,230,410.0 Bytes [100.00%] received. Rate: [2362 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 213
#   1,231,360.0 Bytes [100.00%] received. Rate: [1799 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 214
#   918,070.0 Bytes [100.00%] received. Rate: [1423 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 215
#   167,745.0 Bytes [100.00%] received. Rate: [ 513 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 216
#   1,290,394.0 Bytes [100.00%] received. Rate: [2003 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 217
#   1,840,125.0 Bytes [100.00%] received. Rate: [4787 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 218
#   1,160,326.0 Bytes [100.00%] received. Rate: [1704 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 219
#   1,658,252.0 Bytes [100.00%] received. Rate: [2343 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 220
#   1,007,353.0 Bytes [100.00%] received. Rate: [1642 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 221
#   1,226,598.0 Bytes [100.00%] received. Rate: [2016 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 222
#   645,897.0 Bytes [100.00%] received. Rate: [1178 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 223
#   3,931,197.0 Bytes [100.00%] received. Rate: [3483 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 224
# ERROR: This video is unavailable.
# Sorry about that.
# Error in file :
#   18,673.0 Bytes [100.00%] received. Rate: [ 960 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
#   1,167,553.0 Bytes [100.00%] received. Rate: [8730 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 227
#   738,218.0 Bytes [100.00%] received. Rate: [1328 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 228
#   15,533.0 Bytes [100.00%] received. Rate: [ 724 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# Error in file :
# ERROR: Content Warning
# If the owner of this video has granted you access, please sign in.
#        This video is private.
# Error in file :
#   121,471.0 Bytes [100.00%] received. Rate: [ 453 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 231
#   1,029,008.0 Bytes [100.00%] received. Rate: [1579 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 232
#   1,743,337.0 Bytes [100.00%] received. Rate: [9809 KB/s].  ETA: [0 secs]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# DONE FOR 233

# %%
police_lst[230][:]
# Out:
# ['ORSvarz5uWk', 30.0, 40.0]
